# %% [markdown]
# ### Useful Links

# %% [markdown]
# #### tutorial: https://vimeo.com/554245934/3c56567a80
# #### planning: https://miro.com/app/board/o9J_lxaYHiE=/
# #### TED talk on visualization: https://www.ted.com/talks/hans_rosling_the_best_stats_you_ve_ever_seen?language=en#t-227708
# #### whatsapp group: https://chat.whatsapp.com/Hf11HwFQ6ETJxIdgiXYA41

# %%
# !conda install geopandas
import geopandas as gpd
import pandas as pd
import numpy as np

# %%
# this the address on my own system
sl = "C:/Users/zahraeftekhar/PycharmProjects/TRAIL-Data-Science-Bootcamp-course/Datasets/"

# %%
hospitals = gpd.read_file("{a}Hospitals_VNM.geojson".format(a=sl))
Road = gpd.read_file("{a}Road_Network_VNM.geojson".format(a=sl))
Boundaries =gpd.read_file("{a}Vietnam_Administrative_Boundaries.geojson".format(a=sl))
hospitals.plot()
Road.plot()
len(Boundaries)
# hospitals
# Out:
# 1254

# %%
(Boundaries.area).sum()
# Out:
# C:\Users\ZAHRAE~1\AppData\Local\Temp/ipykernel_15212/1461664671.py:1: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   (Boundaries.area).sum()
# 27.979370991521403

# %%
Boundaries.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
import plotly.express as px
import geopandas as gpd

geo_df = Boundaries
fig = px.choropleth_mapbox(geo_df,
                           geojson=geo_df.geometry,
                           locations=geo_df.index,
#                            color="VARNAME_1",
                           center={"lat": 15.9, "lon": 108.1},
                           mapbox_style="open-street-map",
                           zoom=4)

fig.show()

# %%
Road
# Out:
#      f_code  acc  exs  med  rtt  rsu  loc  soc  rst  \
# 0     AP030    1   28    0  999    1    8  VNM    1
# 1     AP030    1   28    0  999    1    8  VNM    2
# 2     AP030    1   28    0  999    1    8  VNM    2
# 3     AP030    1   28    0   14    1    8  VNM    2
# 4     AP030    1   28    0  999    1    8  VNM    2
# ...     ...  ...  ...  ...  ...  ...  ...  ...  ...
# 4530  AP030    1   28    0  999    1    8  VNM    2
# 4531  AP030    1   28    0   14    1    8  VNM    1
# 4532  AP030    1   28    0   14    1    8  VNM    1
# 4533  AP030    1   28    0  999    1    8  VNM    1
# 4534  AP030    1   28    0   15    1    8  VNM    2
#
#                                                geometry
# 0     LINESTRING (-1324896.810 11005706.981, -132519...
# 1     LINESTRING (-1512457.120 11017791.650, -151150...
# 2     LINESTRING (-1493643.977 11027505.705, -149304...
# 3     LINESTRING (-1512457.120 11017791.650, -151123...
# ...

# %%
(Road.crs)
hospitals.crs
Boundaries.crs
population  = pd.read_csv("{a}Population_VNM_2020_1km_Aggregated_UNadj.csv".format(a=sl))
population
# Out:
#                  X          Y          Z
# 0       105.319583  23.395417  56.801758
# 1       105.294583  23.387083  69.821190
# 2       105.302916  23.387083  61.812702
# 3       105.311250  23.387083  50.627831
# 4       105.319583  23.387083  87.299217
# ...            ...        ...        ...
# 406779  104.894583   8.570417  17.621071
# 406780  104.827916   8.562083  16.502373
# 406781  104.836250   8.562083  31.207506
# 406782  104.844583   8.562083  29.299860
# 406783  104.852916   8.562083   9.704453
#
# [406784 rows x 3 columns]

# %%
(Road.crs)
# Out:
# <Projected CRS: EPSG:32751>
# Name: WGS 84 / UTM zone 51S
# Axis Info [cartesian]:
# - E[east]: Easting (metre)
# - N[north]: Northing (metre)
# Area of Use:
# - name: World - S hemisphere - 120°E to 126°E - by country
# - bounds: (120.0, -80.0, 126.0, 0.0)
# Coordinate Operation:
# - name: UTM zone 51S
# - method: Transverse Mercator
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
population_geo = gpd.GeoDataFrame(population, geometry=gpd.points_from_xy(population.X, population.Y))
population_geo
# Out:
#                  X          Y          Z                    geometry
# 0       105.319583  23.395417  56.801758  POINT (105.31958 23.39542)
# 1       105.294583  23.387083  69.821190  POINT (105.29458 23.38708)
# 2       105.302916  23.387083  61.812702  POINT (105.30292 23.38708)
# 3       105.311250  23.387083  50.627831  POINT (105.31125 23.38708)
# 4       105.319583  23.387083  87.299217  POINT (105.31958 23.38708)
# ...            ...        ...        ...                         ...
# 406779  104.894583   8.570417  17.621071   POINT (104.89458 8.57042)
# 406780  104.827916   8.562083  16.502373   POINT (104.82792 8.56208)
# 406781  104.836250   8.562083  31.207506   POINT (104.83625 8.56208)
# 406782  104.844583   8.562083  29.299860   POINT (104.84458 8.56208)
# 406783  104.852916   8.562083   9.704453   POINT (104.85292 8.56208)
#
# [406784 rows x 4 columns]

# %%
population_geo.crs="EPSG:32751"

# %%
population_geo.crs
population_geo.plot()
# Out:
# <AxesSubplot:>
