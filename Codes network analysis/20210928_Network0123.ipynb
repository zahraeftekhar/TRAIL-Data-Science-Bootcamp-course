# %%
import pandas as pd
import geopandas

# %%
file_path = 'Datasets/Population_VNM_2020_1km_Aggregated_UNadj.csv'
pop = pd.read_csv(file_path)

# %%
pop = geopandas.GeoDataFrame(
    pop, geometry=geopandas.points_from_xy(pop.X, pop.Y))

# %%
pop.rename(columns={'X':'x','Y':'y'},inplace=True)

# %%
vietnamBoundaries = geopandas.read_file('Datasets/Vietnam_Administrative_Boundaries.geojson')

# %%
hospitals = geopandas.read_file('20210930_hospitalsNodesMerge3.shp')

# %%
hospitals
# Out:
#         full_id      osm_id osm_type   amenity building  \
# 0    w267229678   267229678      way  hospital     None
# 1    w531958116   531958116      way  hospital     None
# 2    w531958120   531958120      way  hospital     None
# 3    w538534203   538534203      way  hospital     None
# 4    w557042925   557042925      way  hospital     None
# 5    w557046553   557046553      way  hospital     None
# 6    w557252001   557252001      way  hospital     None
# 7    w559707171   559707171      way  hospital     None
# 8    w559965737   559965737      way  hospital     None
# 9    w571535898   571535898      way  hospital     None
# 10   w579919060   579919060      way  hospital     None
# 11   w605281204   605281204      way  hospital     None
# 12   w616700393   616700393      way  hospital     None
# 13   w631548583   631548583      way  hospital     None
# 14   w638490739   638490739      way  hospital     None
# 15   w647777938   647777938      way  hospital     None
# 16   w685460664   685460664      way  hospital     None
# 17   w686400243   686400243      way  hospital     None
# 18   w688106149   688106149      way  hospital     None
# 19   w688622819   688622819      way  hospital     None
# 20   w689686672   689686672      way  hospital     None
# 21   w709199035   709199035      way  hospital     None
# 22   w731884707   731884707      way  hospital     None
# 23   w841619934   841619934      way  hospital     None
# 24  n4272686492  4272686492     node  hospital     None
# 25  n4663404099  4663404099     node  hospital     None
# 26  n5648653804  5648653804     node  hospital     None
# 27  n5740113949  5740113949     node  hospital     None
# 28  n5740141246  5740141246     node  hospital     None
# 29  n6437373398  6437373398     node  hospital     None
# 30  n6449604779  6449604779     node  hospital     None
# 31  n6468357295  6468357295     node  hospital     None
# 32  n7166348962  7166348962     node  hospital     None
# 33  n7193381786  7193381786     node  hospital     None
# 34  n7668156135  7668156135     node  hospital     None
#
#                                                  name  type     addr_city  \
# 0                   B???nh vi???n Th??? x?? Ph?? M???  None          None
# 1   B???nh vi???n Y h???c c??? truy???n t???nh Qu?...  None          None
# 2           B???nh vi???n ??a khoa t???nh Qu???ng Nam  None          None
# 3                    B???nh vi???n m???t T??y Nguy??n  None          None
# 4                          nh?? thu???c Tu???n Th???o  None          None
# 5                            nh?? thu???c ????ng ????  None          None
# 6                                                None  None          None
# 7                   b???nh vi???n Th??i B??nh D????ng  None          None
# 8   B???nh vi???n Ph??? s???n - Nhi t???nh Qu???ng...  None      Tam K???
# 9                Trung t??m Y t??? huy???n Kon Pl??ng  None          None
# 10                                               None  None          None
# 11               B???nh vi???n Ung B?????u c?? s??? 2  None          None
# 12                                               None  None          None
# 13                 B???nh vi???n ??a khoa D???u Gi??y  None          None
# 14                                               None  None          None
# 15  B???nh vi???n ??i???u d?????ng Ph???c h???i ch...  None    S???m S??n
# 16                       Tr???m y t??? x?? V??nh S??n  None          None
# 17                      Tr???m Y T??? X?? V??nh Quang  None          None
# 18                       Tr???m y t??? Ng?? Th??? nam  None          None
# 19                     Tr???m y t??? x?? ?????c Phong  None          None
# 20         B???nh Vi???n ??a Khoa Th??nh Ph??? Pleiku  None          None
# 21                       ????ng Tri???u Town Hospital  None  Qu???ng Ninh
# 22  B???nh vi???n T??m th???n T???nh B?? R???a - V...  None          None
# 23                            B???nh vi???n s???n nhi  None          None
# 24                        B?nh vi?n ?a khoa Thái Bình  None          None
# 25                                B?nh vi?n H??ng S?n  None          None
# 26                      B?nh vi?n ?a khoa TP Hòa Bình  None          None
# 27                           B?nh Vi?n 211 Tây Nguyên  None          None
# 28                               B?nh vi?n Quân Y 211  None          None
# 29                           B?nh vi?n ?a khoa Phù M?  None          None
# 30                       Trung tâm Y T? Th? Xã T? S?n  None          None
# 31                    B?nh Vi?n ?a Khoa Huy?n Phù Cát  None          None
# 32                            B?nh Vi?n C Thái Nguyên  None          None
# 33                                           Tree Spa  None          None
# 34                          Phòng Khám ?a Khoa B?o An  None          None
#
#         addr_distr addr_house  ... index_righ FID_Raster       Id gridcode  \
# 0             None       None  ...      757.0    63135.0  63135.0      3.0
# 1             None       None  ...      470.0    57560.0  57560.0      3.0
# 2             None       None  ...      470.0    57560.0  57560.0      3.0
# 3             None        309  ...        NaN        NaN      NaN      0.0
# 4             None       None  ...        NaN        NaN      NaN      0.0
# 5             None       None  ...        NaN        NaN      NaN      0.0
# 6             None       None  ...        NaN        NaN      NaN      0.0
# 7             None       None  ...      470.0    57560.0  57560.0      3.0
# 8             None         46  ...      470.0    57560.0  57560.0      3.0
# 9             None       None  ...        NaN        NaN      NaN      0.0
# 10            None       None  ...      321.0    54270.0  54270.0      2.0
# 11        Qu???n 9       None  ...      746.0    62790.0  62790.0      3.0
# 12            None       None  ...      262.0    53396.0  53396.0      3.0
# 13            None       None  ...        NaN        NaN      NaN      0.0
# 14            None       None  ...      262.0    53396.0  53396.0      3.0
# 15            None       None  ...      304.0    53985.0  53985.0      2.0
# 16            None       None  ...      513.0    58712.0  58712.0      2.0
# 17            None       None  ...      538.0    59137.0  59137.0      3.0
# 18            None       None  ...      403.0    56099.0  56099.0      3.0
# 19            None       None  ...      493.0    58111.0  58111.0      2.0
# 20            None       None  ...        NaN        NaN      NaN      0.0
# 21  ????ng Tri???u       None  ...      241.0    53109.0  53109.0      3.0
# 22            None       None  ...        NaN        NaN      NaN      0.0
# 23            None       None  ...      286.0    53653.0  53653.0      3.0
# 24            None       None  ...      262.0    53396.0  53396.0      3.0
# 25            None       None  ...        NaN        NaN      NaN      0.0
# 26            None       None  ...      227.0    53021.0  53021.0      3.0
# 27            None       None  ...        NaN        NaN      NaN      0.0
# 28            None       None  ...        NaN        NaN      NaN      0.0
# 29            None       None  ...        NaN        NaN      NaN      0.0
# 30            None       None  ...      203.0    52790.0  52790.0      2.0
# 31            None       None  ...      533.0    59048.0  59048.0      3.0
# 32            None       None  ...      156.0    52453.0  52453.0      3.0
# 33            None       None  ...        NaN        NaN      NaN      0.0
# 34            None       None  ...      241.0    53109.0  53109.0      3.0
#
#    FID_countr country SUM_Shape_ Shape_Leng Shape_Area  \
# 0         1.0     1.0  27.979371   0.500000   0.013889
# 1         1.0     1.0  27.979371   0.333333   0.006944
# 2         1.0     1.0  27.979371   0.333333   0.006944
# 3         NaN     NaN        NaN        NaN        NaN
# 4         NaN     NaN        NaN        NaN        NaN
# 5         NaN     NaN        NaN        NaN        NaN
# 6         NaN     NaN        NaN        NaN        NaN
# 7         1.0     1.0  27.979371   0.333333   0.006944
# 8         1.0     1.0  27.979371   0.333333   0.006944
# 9         NaN     NaN        NaN        NaN        NaN
# 10        1.0     1.0  27.979371   0.314410   0.004755
# 11        1.0     1.0  27.979371   0.333333   0.006944
# 12        1.0     1.0  27.979371   1.000874   0.034698
# 13        NaN     NaN        NaN        NaN        NaN
# 14        1.0     1.0  27.979371   1.000874   0.034698
# 15        1.0     1.0  27.979371   0.297972   0.002840
# 16        1.0     1.0  27.979371   0.333333   0.006944
# 17        1.0     1.0  27.979371   1.145817   0.044164
# 18        1.0     1.0  27.979371   0.217140   0.001954
# 19        1.0     1.0  27.979371   0.270927   0.002104
# 20        NaN     NaN        NaN        NaN        NaN
# 21        1.0     1.0  27.979371   2.138612   0.113160
# 22        NaN     NaN        NaN        NaN        NaN
# 23        1.0     1.0  27.979371   0.500000   0.013889
# 24        1.0     1.0  27.979371   1.000874   0.034698
# 25        NaN     NaN        NaN        NaN        NaN
# 26        1.0     1.0  27.979371   0.333333   0.006944
# 27        NaN     NaN        NaN        NaN        NaN
# 28        NaN     NaN        NaN        NaN        NaN
# 29        NaN     NaN        NaN        NaN        NaN
# 30        1.0     1.0  27.979371   0.452761   0.009689
# 31        1.0     1.0  27.979371   0.333333   0.006944
# 32        1.0     1.0  27.979371   0.312483   0.004447
# 33        NaN     NaN        NaN        NaN        NaN
# 34        1.0     1.0  27.979371   2.138612   0.113160
#
#                       geometry
# 0   POINT (107.05885 10.59663)
# 1   POINT (108.47723 15.57393)
# 2   POINT (108.47855 15.57185)
# 3   POINT (108.06167 12.69464)
# 4   POINT (105.90519 18.33134)
# 5   POINT (105.90490 18.33239)
# 6   POINT (105.91265 18.32273)
# 7   POINT (108.46519 15.57694)
# 8   POINT (108.46514 15.57123)
# 9   POINT (108.29386 14.59722)
# 10  POINT (104.48929 19.26173)
# 11  POINT (106.80932 10.87026)
# 12  POINT (106.35285 20.43374)
# 13  POINT (107.13899 10.95160)
# 14  POINT (106.33773 20.44082)
# 15  POINT (105.89781 19.73211)
# 16  POINT (108.68732 14.35550)
# 17  POINT (108.80233 14.05134)
# 18  POINT (106.96923 17.17541)
# 19  POINT (108.91854 14.92882)
# 20  POINT (107.99059 13.97936)
# 21  POINT (106.52246 21.07685)
# 22  POINT (107.23567 10.58535)
# 23  POINT (105.96494 20.24176)
# 24  POINT (106.33845 20.44139)
# 25  POINT (105.42688 18.51586)
# 26  POINT (105.33194 20.84621)
# 27  POINT (107.99324 14.01248)
# 28  POINT (107.99484 14.01336)
# 29  POINT (109.04770 14.17016)
# 30  POINT (105.96312 21.11718)
# 31  POINT (109.05955 14.00720)
# 32  POINT (105.86105 21.44668)
# 33  POINT (108.04561 12.67411)
# 34  POINT (106.53908 21.00066)
#
# [35 rows x 114 columns]

# %%
hospitals["x"] = hospitals.centroid.x
hospitals["y"] = hospitals.centroid.y
# Out:
# <ipython-input-8-0d4241c28bf7>:1: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   hospitals["x"] = hospitals.centroid.x
# <ipython-input-8-0d4241c28bf7>:2: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   hospitals["y"] = hospitals.centroid.y

# %%
import osmnx as ox
import networkx as nx
import pandana
import numpy as np

# %%
#from pyrosm import OSM, get_data

# %%
ox.config(use_cache=True, log_console=True)

# %%
#network = ox.graph_from_xml('Datasets/highways2.osm')

# %%
network = ox.load_graphml('Datasets/20211003_graph0123.graphml')

# %%
#file_path = 'Datasets/20210928networkGraph.graphml'
#ox.save_graphml(G, filepath=file_path)

# %%
from sklearn.neighbors import BallTree
import numpy as np
import mapclassify as mc
import matplotlib.pyplot as plt
import time

def get_igraph_nodes(G):
    """Retrieves a frame from nodes of the igaph"""
    attributes = G.vs.attribute_names()
    if len(attributes) == 0:
        raise ValueError("Nodes does not have data.")
    data = {name: G.vs[name] for name in attributes}
    if "geometry" in attributes:
        return gpd.GeoDataFrame(data, 
                                geometry="geometry", 
                                crs="epsg:4326")
    return pd.DataFrame(data)

def get_nearest(src_points, candidates, k_neighbors=1):
    """Find nearest neighbors for all source points from a set of candidate points"""
    tree = BallTree(candidates, leaf_size=15, metric='haversine')
    distances, indices = tree.query(src_points, k=k_neighbors)
    distances = distances.transpose()
    indices = indices.transpose()
    closest = indices[0]
    closest_dist = distances[0]
    return (closest, closest_dist)

def nearest_neighbor(left_gdf, right_gdf, return_dist=False):
    """
    For each point in left_gdf, find closest point in right GeoDataFrame and return them.
    
    For further info, take a look this lesson: 
        https://autogis-site.readthedocs.io/en/latest/notebooks/L3/06_nearest-neighbor-faster.html
    """
    left_geom_col = left_gdf.geometry.name
    right_geom_col = right_gdf.geometry.name
    right = right_gdf.copy().reset_index(drop=True)
    left_radians = np.array(left_gdf[left_geom_col].apply(lambda geom: 
                                                          (geom.x * np.pi / 180, geom.y * np.pi / 180)
                                                         ).to_list())
    right_radians = np.array(right[right_geom_col].apply(lambda geom: 
                                                         (geom.x * np.pi / 180, geom.y * np.pi / 180)
                                                        ).to_list())
    closest, dist = get_nearest(src_points=left_radians, candidates=right_radians)
    closest_points = right.loc[closest]
    closest_points = closest_points.reset_index(drop=True)
    if return_dist:
        earth_radius = 6371000  # meters
        closest_points['distance'] = dist * earth_radius
    return closest_points

def find_nearest_nodeids(nodes, src_gdf):
    """Finds the nearest node-ids for all points in 'src_gdf'."""
    nearest = nearest_neighbor(src_gdf, nodes, return_dist=True)
    return list(set(nearest["node_id"].values)), nearest["distance"].values

# %%
ox.plot_graph(network,node_size=0)
# Out:
# (<Figure size 576x576 with 1 Axes>, <AxesSubplot:>)

# %%
nodes = ox.graph_to_gdfs(network,nodes=True,edges=False)

# %%
edges = ox.graph_to_gdfs(network,nodes=False,edges=True)

# %%
# Create graph
G = network

# %%
edges.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# MultiIndex: 45876 entries, (82546684, 1312706693, 0) to (9109918399, 5961751638, 0)
# Data columns (total 24 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   osmid        45876 non-null  object
#  1   lanes        2165 non-null   object
#  2   name         18081 non-null  object
#  3   highway      45876 non-null  object
#  4   oneway       45876 non-null  bool
#  5   length       45876 non-null  float64
#  6   geometry     45876 non-null  geometry
#  7   ref          14760 non-null  object
#  8   bridge       9155 non-null   object
#  9   access       128 non-null    object
#  10  index_right  23586 non-null  object
#  11  FID_Raster   23586 non-null  object
#  12  Id           23586 non-null  object
#  13  gridcode     45876 non-null  object
#  14  FID_countr   23586 non-null  object
#  15  country      23586 non-null  object
#  16  SUM_Shape_   23586 non-null  object
#  17  Shape_Leng   23586 non-null  object
#  18  Shape_Area   23586 non-null  object
#  19  tunnel       145 non-null    object
#  20  maxspeed     1406 non-null   object
#  21  junction     1531 non-null   object
#  22  width        125 non-null    object
#  23  service      30 non-null     object
# dtypes: bool(1), float64(1), geometry(1), object(21)
# memory usage: 9.6+ MB

# %%
src_ids, euclidean_distance = ox.distance.nearest_nodes(G=network,X=hospitals['x'], Y=hospitals['y'],return_dist=True)

# %%
src_idsPop, euclidean_distancePop = ox.distance.nearest_nodes(G=network,X=pop['x'], Y=pop['y'],return_dist=True)

# %%
import igraph

# %%
src_cnt = len(src_ids)

# %% [raw]
# # Keep track of how many new columns are inserted to the frame
# src_cnt = len(src_ids)
#
# # Iterate over hospitals and calculate the network distances
# # Note: this could also be run by passing all `src_ids` at once
# # to the shortest_paths_dijkstra -function.
# for src_id, src_idPop, distance_to_closest_node, distance_to_closest_node2 in zip(src_ids,src_idsPop,
#                                                                                   euclidean_distance,euclidean_distancePop):
#     #print(f"Calculate shortest paths to {src_id}")
#
#     # Calculate shortest path lengths to given locations
#     path_lengths = ox.shortest_path(G=G,orig=src_id,dest=src_idPop)
#
#     # Calculate shortest path lengths to given locations
#    # path_lengths = ox.shortest_path(G=G,orig=src_id,dest=src_id)
#
#     # Add the euclidean distance between the hospital and closest node in the network
#     # to keep track of the door-to-door travel distance
#     path_lengths = np.array(path_lengths) + distance_to_closest_node + distance_to_closest_node2
#
#     # Attach the path lenghts to nodes
#     nodes[f"distance_to_{src_id}"] = path_lengths[0]

# %%
nodes
# Out:
#                     y           x index_right FID_Raster       Id gridcode  \
# osmid
# 75617751    21.025441  105.853216       230.0    53024.0  53024.0        5
# 75618029    21.024871  105.855136       230.0    53024.0  53024.0        5
# 6644523689  21.025951  105.851667       230.0    53024.0  53024.0        5
# 1748253601  21.031894  105.851772       230.0    53024.0  53024.0        5
# 993037757   21.024378  105.856964       230.0    53024.0  53024.0        5
# ...               ...         ...         ...        ...      ...      ...
# 5961712145  17.929520  106.502736       378.0    55490.0  55490.0        2
# 9109918393  17.932085  106.497181       377.0    55489.0  55489.0        3
# 9109918325  17.932113  106.497145       377.0    55489.0  55489.0        3
# 9109918399  17.932486  106.497915       377.0    55489.0  55489.0        3
# 5961751638  17.941146  106.519288         NaN        NaN      NaN        0
#
#            FID_countr country     SUM_Shape_      Shape_Leng  \
# osmid
# 75617751          1.0     1.0  27.9793709915  0.951570677355
# 75618029          1.0     1.0  27.9793709915  0.951570677355
# 6644523689        1.0     1.0  27.9793709915  0.951570677355
# 1748253601        1.0     1.0  27.9793709915  0.951570677355
# 993037757         1.0     1.0  27.9793709915  0.951570677355
# ...               ...     ...            ...             ...
# 5961712145        1.0     1.0  27.9793709915  0.152850588735
# 9109918393        1.0     1.0  27.9793709915  0.319319892587
# 9109918325        1.0     1.0  27.9793709915  0.319319892587
# 9109918399        1.0     1.0  27.9793709915  0.319319892587
# 5961751638        NaN     NaN            NaN             NaN
#
#                    Shape_Area highway  ref                    geometry
# osmid
# 75617751      0.0340763301485     NaN  NaN  POINT (105.85322 21.02544)
# 75618029      0.0340763301485     NaN  NaN  POINT (105.85514 21.02487)
# 6644523689    0.0340763301485     NaN  NaN  POINT (105.85167 21.02595)
# 1748253601    0.0340763301485     NaN  NaN  POINT (105.85177 21.03189)
# 993037757     0.0340763301485     NaN  NaN  POINT (105.85696 21.02438)
# ...                       ...     ...  ...                         ...
# 5961712145  0.000356803983571     NaN  NaN  POINT (106.50274 17.92952)
# 9109918393   0.00626052081809     NaN  NaN  POINT (106.49718 17.93208)
# 9109918325   0.00626052081809     NaN  NaN  POINT (106.49715 17.93211)
# 9109918399   0.00626052081809     NaN  NaN  POINT (106.49792 17.93249)
# 5961751638                NaN     NaN  NaN  POINT (106.51929 17.94115)
#
# [44647 rows x 14 columns]

# %%
# Calculate distance to the closest hospital
nodes["distance_to_closest"] = nodes.iloc[:, -src_cnt:].min(axis=1)

# At this point you could already see the catchment areas from each road network node 
# to the closest hospital.
# Comment out the following if you want to see:
# ax = nodes.plot(column="distance_to_closest", cmap="RdYlBu", markersize=0.5)
# Out:
# <ipython-input-26-89a1e2adfa50>:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   nodes["distance_to_closest"] = nodes.iloc[:, -src_cnt:].min(axis=1)

# %%
ax = nodes.plot(column="distance_to_closest", cmap="RdYlBu", markersize=0.5)

# %%
hospitals['node_id'] = 0

# %%
nodes["node_id"] = nodes.index

# %%
closest = nearest_neighbor(pop,nodes,return_dist=True)

# %%
closest
# Out:
#                 y           x index_right FID_Raster       Id gridcode  \
# 0       23.361695  105.318230         NaN        NaN      NaN        0
# 1       23.310491  105.296753         NaN        NaN      NaN        0
# 2       23.361695  105.318230         NaN        NaN      NaN        0
# 3       23.361695  105.318230         NaN        NaN      NaN        0
# 4       23.361695  105.318230         NaN        NaN      NaN        0
# ...           ...         ...         ...        ...      ...      ...
# 406779   8.851441  104.938055       837.0    64752.0  64752.0        5
# 406780   8.600705  104.809473       845.0    65021.0  65021.0        2
# 406781   8.600705  104.809473       845.0    65021.0  65021.0        2
# 406782   8.600705  104.809473       845.0    65021.0  65021.0        2
# 406783   8.600705  104.809473       845.0    65021.0  65021.0        2
#
#        FID_countr country     SUM_Shape_      Shape_Leng       Shape_Area  \
# 0             NaN     NaN            NaN             NaN              NaN
# 1             NaN     NaN            NaN             NaN              NaN
# 2             NaN     NaN            NaN             NaN              NaN
# 3             NaN     NaN            NaN             NaN              NaN
# 4             NaN     NaN            NaN             NaN              NaN
# ...           ...     ...            ...             ...              ...
# 406779        1.0     1.0  27.9793709915   2.47097623538   0.151349817713
# 406780        1.0     1.0  27.9793709915  0.326033275684  0.0057658605627
# 406781        1.0     1.0  27.9793709915  0.326033275684  0.0057658605627
# 406782        1.0     1.0  27.9793709915  0.326033275684  0.0057658605627
# 406783        1.0     1.0  27.9793709915  0.326033275684  0.0057658605627
#
#        highway  ref                    geometry  distance_to_closest  \
# 0          NaN  NaN  POINT (105.31823 23.36169)            23.361695
# 1          NaN  NaN  POINT (105.29675 23.31049)            23.310491
# 2          NaN  NaN  POINT (105.31823 23.36169)            23.361695
# 3          NaN  NaN  POINT (105.31823 23.36169)            23.361695
# 4          NaN  NaN  POINT (105.31823 23.36169)            23.361695
# ...        ...  ...                         ...                  ...
# 406779     NaN  NaN   POINT (104.93805 8.85144)             8.851441
# 406780     NaN  NaN   POINT (104.80947 8.60070)             8.600705
# 406781     NaN  NaN   POINT (104.80947 8.60070)             8.600705
# 406782     NaN  NaN   POINT (104.80947 8.60070)             8.600705
# 406783     NaN  NaN   POINT (104.80947 8.60070)             8.600705
#
#            node_id     distance
# 0       2522145872  1001.992361
# 1       7968676755  2259.617990
# 2       2522145872  1858.869236
# 3       2522145872  1076.340540
# 4       2522145872   760.847273
# ...            ...          ...
# 406779  4889231212  9384.317624
# 406780  4889180335  2326.418657
# 406781  4889180335  3173.669261
# 406782  4889180335  4055.785359
# 406783  4889180335  4954.177900
#
# [406784 rows x 17 columns]

# %%
#closest['node_id'] = closest.index

# %%
pop["node_id"] = closest["node_id"]
pop["distance_to_closest_node"] = closest["distance"]

# %%
pop
# Out:
#                  x          y          Z                    geometry  \
# 0       105.319583  23.395417  56.801758  POINT (105.31958 23.39542)
# 1       105.294583  23.387083  69.821190  POINT (105.29458 23.38708)
# 2       105.302916  23.387083  61.812702  POINT (105.30292 23.38708)
# 3       105.311250  23.387083  50.627831  POINT (105.31125 23.38708)
# 4       105.319583  23.387083  87.299217  POINT (105.31958 23.38708)
# ...            ...        ...        ...                         ...
# 406779  104.894583   8.570417  17.621071   POINT (104.89458 8.57042)
# 406780  104.827916   8.562083  16.502373   POINT (104.82792 8.56208)
# 406781  104.836250   8.562083  31.207506   POINT (104.83625 8.56208)
# 406782  104.844583   8.562083  29.299860   POINT (104.84458 8.56208)
# 406783  104.852916   8.562083   9.704453   POINT (104.85292 8.56208)
#
#            node_id  distance_to_closest_node
# 0       2522145872               1001.992361
# 1       7968676755               2259.617990
# 2       2522145872               1858.869236
# 3       2522145872               1076.340540
# 4       2522145872                760.847273
# ...            ...                       ...
# 406779  4889231212               9384.317624
# 406780  4889180335               2326.418657
# 406781  4889180335               3173.669261
# 406782  4889180335               4055.785359
# 406783  4889180335               4954.177900
#
# [406784 rows x 6 columns]

# %%
access = pop.merge(nodes[["distance_to_closest", "node_id"]], on="node_id")

# %%
# Add the (Euclidean) distance between building 
# and the closest node in the road network to get a full "door-to-door" distance
access["distance"] = access["distance_to_closest"] + access["distance_to_closest_node"]

# Calculate distance in kilometers (meters by default)
access["distance_km"] = (access["distance"] / 1000).round(1)

# %%
access.head(2)
# Out:
#             x          y          Z                    geometry     node_id  \
# 0  105.319583  23.395417  56.801758  POINT (105.31958 23.39542)  2522145872
# 1  105.302916  23.387083  61.812702  POINT (105.30292 23.38708)  2522145872
#
#    distance_to_closest_node  distance_to_closest     distance  distance_km
# 0               1001.992361            23.361695  1025.354055          1.0
# 1               1858.869236            23.361695  1882.230931          1.9

# %%
# Classify distances to every 2 km zones, specify that the upper boundary is 50 kilometer
# everything above this will be put into a same class
upper_boundary_distance = 10
width = 1

# Use self-defined classification
classifier = mc.UserDefined(access["distance_km"], bins=[x for x in range(0, int(upper_boundary_distance)+1, width)])
access["cls"] = access[["distance_km"]].apply(classifier)
# Replace the class numbers to distance categories (e.g. 0-2, 2-4 .. km etc.)
access["travel_distance"] = access["cls"].replace({k: v 
                                                   for k, v in 
                                                   zip([x for x in range(len(classifier.bins))], 
                                                       classifier.bins)})

# Set all values over 50 km as 51 (to improve how the colorscale works)
access.loc[access["travel_distance"] > upper_boundary_distance, "travel_distance"] = upper_boundary_distance + 1

# Convert the observation counts as percentages
classifier.counts = (classifier.counts / classifier.counts.sum()).round(3)

# Convert stats to dataframe
bins = classifier.bins.astype(int)
categories = np.vstack([bins[:-1], bins[1:]]).T
categories = [f"{low}-{high}" for low, high in categories]
access_zone_classes = pd.DataFrame({"Distance": categories, "% of pop nodes": classifier.counts[1:]})

# %%
access['Zpct'] = (access.Z / access.Z.sum())*100

# %%
# percentage of people living further away than 2km
access[access['distance_km'] <= 1]['Zpct'].sum()
# Out:
# 73.0211930778096

# %%
access[access['cls']==10]
# Out:
#                  x          y           Z                    geometry  \
# 54884   102.686250  21.712083   22.845865  POINT (102.68625 21.71208)
# 54887   102.686250  21.703750   21.549856  POINT (102.68625 21.70375)
# 54889   102.677916  21.695417   18.094612  POINT (102.67792 21.69542)
# 54890   102.686250  21.695417   20.977667  POINT (102.68625 21.69542)
# 54892   102.677916  21.687083   22.837444  POINT (102.67792 21.68708)
# ...            ...        ...         ...                         ...
# 392839  104.927916   9.687083  123.142799   POINT (104.92792 9.68708)
# 392840  104.919583   9.678750  120.374771   POINT (104.91958 9.67875)
# 392843  104.919583   9.670417  113.156837   POINT (104.91958 9.67042)
# 406033  104.894583   8.578750   61.723495   POINT (104.89458 8.57875)
# 406038  104.894583   8.570417   17.621071   POINT (104.89458 8.57042)
#
#            node_id  distance_to_closest_node  distance_to_closest  \
# 54884   8251039852               9070.641067            22.045817
# 54887   8251039852               9253.400929            22.045817
# 54889   8251039852               9079.922128            22.045817
# 54890   8251039852               9436.997307            22.045817
# 54892   8251039852               9271.288727            22.045817
# ...            ...                       ...                  ...
# 392839  7937101066               9103.424182             9.409308
# 392840  7937101066               9386.682951             9.409308
# 392843  7937101066               9191.017568             9.409308
# 406033  4889231212               9180.697406             8.851441
# 406038  4889231212               9384.317624             8.851441
#
#            distance  distance_km  cls  travel_distance      Zpct
# 54884   9092.686884          9.1   10             10.0  0.000023
# 54887   9275.446745          9.3   10             10.0  0.000022
# 54889   9101.967944          9.1   10             10.0  0.000019
# 54890   9459.043124          9.5   10             10.0  0.000022
# 54892   9293.334543          9.3   10             10.0  0.000023
# ...             ...          ...  ...              ...       ...
# 392839  9112.833490          9.1   10             10.0  0.000127
# 392840  9396.092259          9.4   10             10.0  0.000124
# 392843  9200.426876          9.2   10             10.0  0.000116
# 406033  9189.548846          9.2   10             10.0  0.000063
# 406038  9393.169064          9.4   10             10.0  0.000018
#
# [1093 rows x 12 columns]

# %%
round(access.groupby('cls')['Zpct'].sum(),1)
# Out:
# cls
# 0      2.0
# 1     71.1
# 2     16.6
# 3      5.4
# 4      2.4
# 5      1.2
# 6      0.6
# 7      0.3
# 8      0.1
# 9      0.1
# 10     0.0
# 11     0.2
# Name: Zpct, dtype: float64

# %%
access_zone_classes
# Out:
#    Distance  % of pop nodes
# 0       0-1           0.304
# 1       1-2           0.272
# 2       2-3           0.170
# 3       3-4           0.104
# 4       4-5           0.064
# 5       5-6           0.039
# 6       6-7           0.021
# 7       7-8           0.010
# 8       8-9           0.005
# 9      9-10           0.003
# 10   10-114           0.006

# %%
pd.DataFrame(access.groupby('cls')['Zpct'].sum()).reset_index().merge(access_zone_classes['Distance'],left_index=True,right_index=True)
# Out:
#     cls       Zpct Distance
# 0     0   1.962637      0-1
# 1     1  71.058556      1-2
# 2     2  16.583313      2-3
# 3     3   5.358955      3-4
# 4     4   2.381987      4-5
# 5     5   1.215459      5-6
# 6     6   0.644884      6-7
# 7     7   0.328281      7-8
# 8     8   0.147811      8-9
# 9     9   0.067113     9-10
# 10   10   0.045981   10-114

# %%
# Say, "the default sans-serif font is COMIC SANS"
plt.rcParams['font.sans-serif'] = "Helvetica"
# Then, "ALWAYS use sans-serif fonts"
plt.rcParams['font.family'] = "sans-serif"

# %%
fig, ax = plt.subplots(figsize=(8,6))
pd.DataFrame(access.groupby('cls')['Zpct'].sum()).reset_index().merge(access_zone_classes['Distance'],left_index=True,right_index=True)['Zpct'].plot(x='cls',kind='bar',color='burlywood',ax=ax,edgecolor='black')
plt.xlabel("Distance class")
plt.ylabel("Percentage of population")
ax.set_ylim([0,80])
plt.savefig('20211003_PeopleRangeScenario0123.svg',format='svg')
plt.savefig('20211003_PeopleRangeScenario0123.eps',format='eps')

# %%
plt.style.use('seaborn-white')

fig, ax = plt.subplots(figsize=(16,14))
access.plot(ax=ax,column="travel_distance", markersize=0.5, legend=True, cmap="YlOrRd", figsize=(17,10))

ax.tick_params(
    axis='both', bottom=False, left=False,         
    labelbottom=False, labelleft=False) 

# Adjust the map extent
#ax.set_xlim(22.5, 30.5)
#ax.set_ylim(57.4, 59.9)
# Add some useful info
ax.text(x=104, y=25, s=f"Network distance (km) from {round(pop['Z'].sum()/1000000)}M people to closest hospital (n={src_cnt}) in Vietnam.")
ax.text(x=114,y=8, s=pd.DataFrame(access.groupby('cls')['Zpct'].sum()).reset_index().merge(access_zone_classes['Distance'],left_index=True,right_index=True).to_string(index=False),
        ha='right', linespacing=1.1);

plt.savefig('20211003_NetworkDistanceScenarioScenario0123.svg',format='svg')
plt.savefig('20211003_NetworkDistanceScenarioScenario0123.eps',format='eps')

# %%
plt.style.use('dark_background')
ax = hospitals.plot(markersize=5, figsize=(17,10))

# %%
access[access['distance_km'] > 5].plot(markersize=5, figsize=(17,10))
# Out:
# <AxesSubplot:>

# %%
#access['distance'].plot(kind='bar')
