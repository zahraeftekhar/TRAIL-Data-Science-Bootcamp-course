# %%
import pandas as pd
import geopandas

# %%
file_path = 'Datasets/Population_VNM_2020_1km_Aggregated_UNadj.csv'
pop = pd.read_csv(file_path)

# %%
#pop2.head()

# %%
pop = geopandas.GeoDataFrame(
    pop, geometry=geopandas.points_from_xy(pop.X, pop.Y))

# %%
#pop.plot(figsize=(12,12))

# %%
vietnamBoundaries = geopandas.read_file('Datasets/Vietnam_Administrative_Boundaries.geojson')

# %%
vietnamBoundaries.head(2)
# Out:
#   GID_0   NAME_0    GID_1    NAME_1 VARNAME_1 NL_NAME_1 TYPE_1 ENGTYPE_1  \
# 0   VNM  Vietnam  VNM.1_1  An Giang  An Giang      None   Tỉnh  Province
# 1   VNM  Vietnam  VNM.2_1  Bạc Liêu  Bac Lieu      None   Tỉnh  Province
#
#    CC_1 HASC_1                                           geometry
# 0  None  VN.AG  POLYGON ((105.37450 10.24604, 105.33623 10.234...
# 1  None  VN.BL  POLYGON ((105.41638 9.01717, 105.41731 9.02926...

# %%
#vietnamBoundaries

# %%
hospitals = geopandas.read_file('Datasets/Hospitals_VNM.geojson')

# %%
hospitals["X"] = hospitals.centroid.x
hospitals["Y"] = hospitals.centroid.y
# Out:
# <ipython-input-10-2f19d28adbbb>:1: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   hospitals["X"] = hospitals.centroid.x
# <ipython-input-10-2f19d28adbbb>:2: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   hospitals["Y"] = hospitals.centroid.y

# %%
hospitals.head(2)
# Out:
#     full_id   osm_id  osm_type   amenity building  \
# 0  r7247040  7247040  relation  hospital      yes
# 1  r7778108  7778108  relation  hospital      yes
#
#                                      name          type addr_city addr_distr  \
# 0          B???nh Vi???n ??a Khoa Long An  multipolygon      None       None
# 1  B???nh Vi???n ??a Khoa T??nh Ph?? Y??n  multipolygon      None       None
#
#   addr_house  ... access traffic_calming entrance addr:ward motor_vehicle  \
# 0       None  ...   None            None     None      None          None
# 1       None  ...   None            None     None      None          None
#
#   crossing                                               path  \
# 0     None  /private/var/folders/0f/4nhftck93tb1h8b_sccxzd...
# 1     None  /private/var/folders/0f/4nhftck93tb1h8b_sccxzd...
#
#                      geometry           X          Y
# 0  POINT (106.42624 10.53229)  106.426238  10.532295
# 1  POINT (109.29928 13.10932)  109.299278  13.109323
#
# ...

# %%
hospitals.plot()
# Out:
# <AxesSubplot:>

# %%
roadNetwork = geopandas.read_file('Datasets/Road_Network_VNM.geojson')

# %%
roadNetwork.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 4535 entries, 0 to 4534
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   f_code    4535 non-null   object
#  1   acc       4535 non-null   int64
#  2   exs       4535 non-null   int64
#  3   med       4535 non-null   int64
#  4   rtt       4535 non-null   int64
#  5   rsu       4535 non-null   int64
#  6   loc       4535 non-null   int64
#  7   soc       4535 non-null   object
#  8   rst       4535 non-null   int64
#  9   geometry  4535 non-null   geometry
# dtypes: geometry(1), int64(7), object(2)
# memory usage: 354.4+ KB

# %%
#roadNetwork.plot(figsize=(20,20))

# %%
roadNetwork.head(2)
# Out:
#   f_code  acc  exs  med  rtt  rsu  loc  soc  rst  \
# 0  AP030    1   28    0  999    1    8  VNM    1
# 1  AP030    1   28    0  999    1    8  VNM    2
#
#                                             geometry
# 0  LINESTRING (-1324896.810 11005706.981, -132519...
# 1  LINESTRING (-1512457.120 11017791.650, -151150...

# %%
roadNetwork['points'] = roadNetwork.apply(lambda x: [y for y in x['geometry'].coords], axis=1)

# %%
roadNetwork.head(5)
# Out:
#   f_code  acc  exs  med  rtt  rsu  loc  soc  rst  \
# 0  AP030    1   28    0  999    1    8  VNM    1
# 1  AP030    1   28    0  999    1    8  VNM    2
# 2  AP030    1   28    0  999    1    8  VNM    2
# 3  AP030    1   28    0   14    1    8  VNM    2
# 4  AP030    1   28    0  999    1    8  VNM    2
#
#                                             geometry  \
# 0  LINESTRING (-1324896.810 11005706.981, -132519...
# 1  LINESTRING (-1512457.120 11017791.650, -151150...
# 2  LINESTRING (-1493643.977 11027505.705, -149304...
# 3  LINESTRING (-1512457.120 11017791.650, -151123...
# 4  LINESTRING (-1509640.460 11037037.887, -151075...
#
#                                               points
# 0  [(-1324896.8100718018, 11005706.980635073), (-...
# 1  [(-1512457.1196527877, 11017791.649970286), (-...
# 2  [(-1493643.9765005666, 11027505.704598242), (-...
# 3  [(-1512457.1196527877, 11017791.649970286), (-...
# 4  [(-1509640.4599902316, 11037037.887330119), (-...

# %%
from pyrosm import OSM

# %%
from pyrosm import get_data

# %%
import osmnx as ox
import networkx as nx
import pandana
import numpy as np

# %%
ox.config(use_cache=True, log_console=True)

# %%
network = ox.graph_from_xml('Datasets/highways2.osm')

# %%
nodes, edges = roadNetwork.get_network(nodes=True,edges=True,network_type="driving")

# %%
ox.plot_graph(network, figsize = (10,10), node_color='red', node_alpha=0.5, node_size=1)

# %%
print(network)
# Out:
# MultiDiGraph with 44647 nodes and 105163 edges

# %%
orig
# Out:
# 75617751

# %%
dest
# Out:
# 9120652278

# %%
geoVietnamRoads = ox.graph_to_gdfs(network, nodes=True)

# %%
geoVietnamRoadsDF = geoVietnamRoads[0].reset_index()

# %%
geoVietnamRoadsDF
# Out:
#             osmid          y           x highway  ref  \
# 0        75617751  21.025441  105.853216     NaN  NaN
# 1        75618029  21.024871  105.855136     NaN  NaN
# 2        76483008  21.080720  105.788689     NaN  NaN
# 3        80399585  10.702306  105.108761     NaN  NaN
# 4        81804025  21.027742  105.834221     NaN  NaN
# ...           ...        ...         ...     ...  ...
# 44642  9115673217  22.835425  106.529890     NaN  NaN
# 44643  9115673220  22.836572  106.528676     NaN  NaN
# 44644  9115673228  22.837678  106.527039     NaN  NaN
# 44645  9115673344  22.815539  106.779454     NaN  NaN
# 44646  9120652278  10.781747  106.706696     NaN  NaN
#
#                          geometry
# 0      POINT (105.85322 21.02544)
# 1      POINT (105.85514 21.02487)
# 2      POINT (105.78869 21.08072)
# 3      POINT (105.10876 10.70231)
# 4      POINT (105.83422 21.02774)
# ...                           ...
# 44642  POINT (106.52989 22.83543)
# ...

# %%
orig = list(network)[0]
dest = list(network)[-1]
route = nx.shortest_path(network, orig, dest, weight='length')
fig, ax = ox.plot_graph_route(network, route, route_linewidth=6, node_size=0, bgcolor='k')

# %%
from sklearn.neighbors import BallTree

# %%
geoVietnamRoadsDF
# Out:
#             osmid          y           x highway  ref  \
# 0        75617751  21.025441  105.853216     NaN  NaN
# 1        75618029  21.024871  105.855136     NaN  NaN
# 2        76483008  21.080720  105.788689     NaN  NaN
# 3        80399585  10.702306  105.108761     NaN  NaN
# 4        81804025  21.027742  105.834221     NaN  NaN
# ...           ...        ...         ...     ...  ...
# 44642  9115673217  22.835425  106.529890     NaN  NaN
# 44643  9115673220  22.836572  106.528676     NaN  NaN
# 44644  9115673228  22.837678  106.527039     NaN  NaN
# 44645  9115673344  22.815539  106.779454     NaN  NaN
# 44646  9120652278  10.781747  106.706696     NaN  NaN
#
#                          geometry
# 0      POINT (105.85322 21.02544)
# 1      POINT (105.85514 21.02487)
# 2      POINT (105.78869 21.08072)
# 3      POINT (105.10876 10.70231)
# 4      POINT (105.83422 21.02774)
# ...                           ...
# 44642  POINT (106.52989 22.83543)
# ...

# %%
nodes = ox.graph_to_gdfs(network,nodes=True,edges=False)

# %%
nodes.head()
# Out:
#                   y           x highway  ref                    geometry
# osmid
# 75617751  21.025441  105.853216     NaN  NaN  POINT (105.85322 21.02544)
# 75618029  21.024871  105.855136     NaN  NaN  POINT (105.85514 21.02487)
# 76483008  21.080720  105.788689     NaN  NaN  POINT (105.78869 21.08072)
# 80399585  10.702306  105.108761     NaN  NaN  POINT (105.10876 10.70231)
# 81804025  21.027742  105.834221     NaN  NaN  POINT (105.83422 21.02774)

# %%
edges = ox.graph_to_gdfs(network,nodes=False,edges=True)

# %%
hospitals['geometry']
# Out:
# 0      POINT (106.42624 10.53229)
# 1      POINT (109.29928 13.10932)
# 2      POINT (106.71826 10.73249)
# 3      POINT (105.85027 21.02464)
# 4      POINT (108.20728 16.05423)
#                   ...
# 946    POINT (105.81999 21.00850)
# 947    POINT (105.81979 21.00876)
# 948    POINT (107.58787 16.46348)
# 949    POINT (105.55699 21.10371)
# 950    POINT (105.84764 21.24987)
# Name: geometry, Length: 951, dtype: geometry

# %%
### finding the nearest network nodes to each hospital
origin_node, euclidean_distance = ox.distance.nearest_nodes(G=network,X=hospitals['X'], Y=hospitals['Y'],return_dist=True)

# %%
pop.head(2)
# Out:
#                      X                    Y                    Z  \
# 0  105.319582923400034  23.3954167719771462        56.8017578125
# 1   105.29458292350003  23.3870834386771485  69.8211898803710938
#
#                      geometry
# 0  POINT (105.31958 23.39542)
# 1  POINT (105.29458 23.38708)

# %%
pop['X'] = pop['X'].astype(float)
pop['Y'] = pop['Y'].astype(float)

# %%
### finding nearest network nodes to each population nucleus
destination_node, euclidean_distanceDestToNode = ox.distance.nearest_nodes(G=network, X=pop['X'], Y=pop['Y'],return_dist=True)

# %%
dataframeHospitalNodes = pd.DataFrame(ox.distance.nearest_nodes(G=network,X=hospitals['X'], Y=hospitals['Y'],return_dist=True)[0])

# %%
dataframeHospitalNodes['length'] = pd.DataFrame(ox.distance.nearest_nodes(G=network,X=hospitals['X'], Y=hospitals['Y'],return_dist=True)[1])

# %%
hospitals.head(2)
# Out:
#     full_id   osm_id  osm_type   amenity building  \
# 0  r7247040  7247040  relation  hospital      yes
# 1  r7778108  7778108  relation  hospital      yes
#
#                                      name          type addr_city addr_distr  \
# 0          B???nh Vi???n ??a Khoa Long An  multipolygon      None       None
# 1  B???nh Vi???n ??a Khoa T??nh Ph?? Y??n  multipolygon      None       None
#
#   addr_house  ... entrance addr:ward motor_vehicle crossing  \
# 0       None  ...     None      None          None     None
# 1       None  ...     None      None          None     None
#
#                                                 path  \
# 0  /private/var/folders/0f/4nhftck93tb1h8b_sccxzd...
# 1  /private/var/folders/0f/4nhftck93tb1h8b_sccxzd...
#
#                      geometry           x          y           X          Y
# 0  POINT (106.42624 10.53229)  106.426238  10.532295  106.426238  10.532295
# 1  POINT (109.29928 13.10932)  109.299278  13.109323  109.299278  13.109323
#
# ...

# %%
dataframeHospitalNodes.rename(columns={0:'Node-id'},inplace=True)

# %%
dataFrameHospitalNetworkNodes = dataframeHospitalNodes.merge(hospitals['full_id'],left_index=True,right_index=True)

# %%
dataFrameHospitalNetworkNodes = dataFrameHospitalNetworkNodes[['full_id','Node-id','length']]

# %%
dataFrameHospitalNetworkNodes.head(2)
# Out:
#     full_id     Node-id      length
# 0  r7247040   897154820  887.020674
# 1  r7778108  1644008794  199.567400

# %%
hospitalsDf = hospitals[['full_id','X','Y']]

# %%
nodes.head(2)
# Out:
#                   y           x highway  ref                    geometry
# osmid
# 75617751  21.025441  105.853216     NaN  NaN  POINT (105.85322 21.02544)
# 75618029  21.024871  105.855136     NaN  NaN  POINT (105.85514 21.02487)

# %%
### Create copy of graph to connect hospitals and population nodes
graphConnected = network.copy()

# %%
### add edges
graphConnected.add_weighted_edges_from(list(dataFrameHospitalNetworkNodes.to_records(index=False)),weight='length')

# %%
ox.plot_graph(network, figsize = (6,6), node_color='red', node_alpha=0.5, node_size=1)
# Out:
# (<Figure size 432x432 with 1 Axes>, <AxesSubplot:>)

# %%
hospitalsDf.rename(columns={'X':'x','Y':'y'},inplace=True)
# Out:
# C:\Users\s130091\Anaconda3\envs\geo_env39\lib\site-packages\pandas\core\frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
len(pop)
# Out:
# 406784

# %%
pd.DataFrame(euclidean_distanceDestToNode)[0].mean()
# Out:
# 4474.932463512836

# %%
### create attribute table for the population nodes
### add unique identifier for each population node
pop['pop_id'] = 'p' + pop.index.astype(str)

# %%
vietnamBoundaries
# Out:
#      GID_0   NAME_0     GID_1       NAME_1    VARNAME_1 NL_NAME_1 TYPE_1  \
# 0      VNM  Vietnam   VNM.1_1     An Giang     An Giang      None   Tỉnh
# 1      VNM  Vietnam   VNM.2_1     Bạc Liêu     Bac Lieu      None   Tỉnh
# 2      VNM  Vietnam   VNM.3_1    Bắc Giang    Bac Giang      None   Tỉnh
# 3      VNM  Vietnam   VNM.4_1      Bắc Kạn      Bac Kan      None   Tỉnh
# 4      VNM  Vietnam   VNM.5_1     Bắc Ninh     Bac Ninh      None   Tỉnh
# ...    ...      ...       ...          ...          ...       ...    ...
# 1249   VNM  Vietnam  VNM.59_1     Trà Vinh     Tra Vinh      None   Tỉnh
# 1250   VNM  Vietnam  VNM.60_1  Tuyên Quang  Tuyen Quang      None   Tỉnh
# 1251   VNM  Vietnam  VNM.61_1    Vĩnh Long    Vinh Long      None   Tỉnh
# 1252   VNM  Vietnam  VNM.62_1    Vĩnh Phúc    Vinh Phuc      None   Tỉnh
# 1253   VNM  Vietnam  VNM.63_1      Yên Bái      Yen Bai      None   Tỉnh
#
#      ENGTYPE_1  CC_1 HASC_1                                           geometry
# ...

# %%
pop['Z'].sum()

# %%
pop['Z'].max()

# %%
### adding node attributes (x and y) to a dictionary
node_attr_hospitals = hospitalsDf.set_index('full_id').to_dict('index')

# %%
hospitalsDf.head(2)
# Out:
#     full_id           x          y
# 0  r7247040  106.426238  10.532295
# 1  r7778108  109.299278  13.109323

# %%
hospitalsDf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 951 entries, 0 to 950
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   full_id  951 non-null    object
#  1   x        951 non-null    float64
#  2   y        951 non-null    float64
# dtypes: float64(2), object(1)
# memory usage: 22.4+ KB

# %%
nx.set_node_attributes(graphConnected, node_attr_hospitals)

# %%
node_attr_hospitals
# Out:
# {'r7247040': {'x': 106.42623815878135, 'y': 10.532294756849197},
#  'r7778108': {'x': 109.29927845493302, 'y': 13.10932330131382},
#  'r7951022': {'x': 106.71825978710329, 'y': 10.73249235098924},
#  'r9790506': {'x': 105.8502689157803, 'y': 21.024644069147595},
#  'w118673887': {'x': 108.20727819559241, 'y': 16.05423122443224},
#  'w118916456': {'x': 105.75580085382111, 'y': 10.029470411500299},
#  'w125294543': {'x': 106.68031422330377, 'y': 10.819213091596495},
#  'w127299413': {'x': 106.69411467810532, 'y': 10.803944799362798},
#  'w127299415': {'x': 106.69453916434863, 'y': 10.803202620475554},
#  'w136259226': {'x': 105.81498802637834, 'y': 21.012390442106177},
#  'w136271003': {'x': 105.76151771724886, 'y': 21.02312735618074},
#  'w158708608': {'x': 106.71794000424725, 'y': 10.732460773386123},
#  'w158971987': {'x': 106.71779920819282, 'y': 10.733501952539035},
#  'w159949212': {'x': 105.81204476264816, 'y': 21.040088484116705},
# ...

# %%
ox.plot_graph(graphConnected, figsize = (6,6), node_color='red', node_alpha=0.5, node_size=1)
# Out:
# (<Figure size 432x432 with 1 Axes>, <AxesSubplot:>)

# %%
edges.head(2)
# Out:
#                             osmid lanes            name    highway  oneway  \
# u        v          key
# 75617751 75618029   0     9965723     2  Phố Tràng Tiền  secondary   False
#          6644523689 0    27933445     2   Phố Hàng Khay  secondary   False
#
#                           length  \
# u        v          key
# 75617751 75618029   0    209.413
#          6644523689 0    170.596
#
#                                                                   geometry  \
# u        v          key
# 75617751 75618029   0    LINESTRING (105.85322 21.02544, 105.85341 21.0...
#          6644523689 0    LINESTRING (105.85322 21.02544, 105.85307 21.0...
#
#                         junction  ref maxspeed bridge access tunnel width  \
# u        v          key
# 75617751 75618029   0        NaN  NaN      NaN    NaN    NaN    NaN   NaN
#          6644523689 0        NaN  NaN      NaN    NaN    NaN    NaN   NaN
#
#                         service est_width
# u        v          key
# ...

# %%
len(destination_node)
# Out:
# 406784

# %%
len(origin_node)
# Out:
# 951

# %%
nodes
# Out:
#                     y           x highway  ref                    geometry
# osmid
# 75617751    21.025441  105.853216     NaN  NaN  POINT (105.85322 21.02544)
# 75618029    21.024871  105.855136     NaN  NaN  POINT (105.85514 21.02487)
# 76483008    21.080720  105.788689     NaN  NaN  POINT (105.78869 21.08072)
# 80399585    10.702306  105.108761     NaN  NaN  POINT (105.10876 10.70231)
# 81804025    21.027742  105.834221     NaN  NaN  POINT (105.83422 21.02774)
# ...               ...         ...     ...  ...                         ...
# 9115673217  22.835425  106.529890     NaN  NaN  POINT (106.52989 22.83543)
# 9115673220  22.836572  106.528676     NaN  NaN  POINT (106.52868 22.83657)
# 9115673228  22.837678  106.527039     NaN  NaN  POINT (106.52704 22.83768)
# 9115673344  22.815539  106.779454     NaN  NaN  POINT (106.77945 22.81554)
# 9120652278  10.781747  106.706696     NaN  NaN  POINT (106.70670 10.78175)
#
# [44647 rows x 5 columns]

# %%
destination_node
# Out:
# [76483008,
#  80399585,
#  80399585,
#  80399585,
#  80399585,
#  80399585,
#  80399585,
#  80399585,
#  80399585,
#  80399585,
#  80399585,
#  80399585,
#  82528020,
#  82528020,
#  82528020,
#  82528020,
#  82528020,
#  82528020,
#  82545909,
#  82545909,
#  82545909,
#  82545909,
#  82545910,
#  82546684,
#  82546684,
#  82546684,
#  82546684,
#  82546684,
#  82547352,
#  82547352,
#  88985933,
#  88985933,
#  88985943,
#  88995576,
#  88995576,
#  88995576,
#  88995576,
#  88995576,
#  88995576,
#  88995576,
#  88995576,
#  88995576,
#  91674481,
#  91674481,
#  91674481,
#  91674481,
#  91674481,
#  91674481,
#  91674481,
#  91674481,
#  91674481,
#  91674481,
#  91674481,
#  91674481,
#  91674481,
#  91674481,
#  91674481,
#  91674481,
#  91674481,
#  91674481,
#  91674485,
#  91674485,
#  91674487,
#  91674487,
#  91674487,
#  91674487,
#  91674487,
#  91674487,
#  91674487,
#  91674487,
#  91674487,
#  91674487,
#  91674487,
#  91674487,
#  91674489,
#  91674489,
# ...

# %%
destination_node[0]
# Out:
# 76483008

# %%
ox.distance.k_shortest_paths(G=network, orig=destination_node,dest=origin_node, k=10)
# Out:
# <generator object k_shortest_paths at 0x0000018812B973C0>

# %%
src_ids
# Out:
# [897154820,
#  1644008794,
#  2210777324,
#  98009137,
#  2623083091,
#  1781132140,
#  5467207470,
#  366469145,
#  5778872969,
#  283138280,
#  5719142231,
#  2210777324,
#  5781192505,
#  106094001,
#  1728445099,
#  6981971968,
#  1314209723,
#  8329563286,
#  6646055121,
#  5248730179,
#  5450285317,
#  5450285305,
#  1044053711,
#  5450571348,
#  6542096256,
#  5447261759,
#  5283621338,
#  1558439959,
#  1558439959,
#  5448246425,
#  1619283902,
#  1619283902,
#  1619283902,
#  1561195920,
#  4888791927,
#  6637713501,
#  1619283827,
#  5079378706,
#  5079378706,
#  411926594,
#  411919362,
#  6754230751,
#  6772593453,
#  366454289,
#  366466608,
#  5780574590,
#  4109567455,
#  5780574590,
#  366370846,
#  4628956511,
#  411926251,
#  2037755924,
#  3806810443,
#  3505558438,
#  5828999547,
#  2598936715,
#  5168420723,
#  5701309405,
#  150350260,
#  319490487,
#  2096511754,
#  419939530,
#  1557920348,
#  2338831823,
#  1657186186,
#  411926439,
#  2332935439,
# ...

# %%
from pyrosm import OSM

# %%
import pyrosm

# %%
nodes.head()
# Out:
#                   y           x highway  ref                    geometry
# osmid
# 75617751  21.025441  105.853216     NaN  NaN  POINT (105.85322 21.02544)
# 75618029  21.024871  105.855136     NaN  NaN  POINT (105.85514 21.02487)
# 76483008  21.080720  105.788689     NaN  NaN  POINT (105.78869 21.08072)
# 80399585  10.702306  105.108761     NaN  NaN  POINT (105.10876 10.70231)
# 81804025  21.027742  105.834221     NaN  NaN  POINT (105.83422 21.02774)

# %%
edges.head()
# Out:
#                                                                      osmid  \
# u        v          key
# 75617751 75618029   0                                              9965723
#          6644523689 0                                             27933445
#          1748253601 0    [28191235, 707035045, 707036649, 965041066, 70...
# 75618029 75617751   0                                              9965723
#          993037757  0                                            605230286
#
#                           lanes                 name    highway  oneway  \
# u        v          key
# 75617751 75618029   0         2       Phố Tràng Tiền  secondary   False
#          6644523689 0         2        Phố Hàng Khay  secondary   False
#          1748253601 0    [4, 3]  Phố Đinh Tiên Hoàng   tertiary    True
# 75618029 75617751   0         2       Phố Tràng Tiền  secondary   False
#          993037757  0         2       Phố Tràng Tiền  secondary   False
#
# ...

# %%
hospitals
# Out:
#          full_id      osm_id  osm_type   amenity building  \
# 0       r7247040     7247040  relation  hospital      yes
# 1       r7778108     7778108  relation  hospital      yes
# 2       r7951022     7951022  relation  hospital     None
# 3       r9790506     9790506  relation  hospital     None
# 4     w118673887   118673887       way  hospital     None
# ..           ...         ...       ...       ...      ...
# 946  n8727775018  8727775018      node               None
# 947  n8727775058  8727775058      node               None
# 948  n8727922178  8727922178      node               None
# 949  n8736112463  8736112463      node               None
# 950  n8741158303  8741158303      node               None
#
#                                        name          type       addr_city  \
# 0            B???nh Vi???n ??a Khoa Long An  multipolygon            None
# 1    B???nh Vi???n ??a Khoa T??nh Ph?? Y??n  multipolygon            None
# ...
